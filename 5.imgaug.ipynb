# %%
from keras.preprocessing.image import img_to_array,array_to_img,load_img
import imgaug as ia
import matplotlib.pyplot as plt
from PIL import Image
# Out:
# Using TensorFlow backend.
# d:\envs\pro\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\envs\pro\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\envs\pro\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\envs\pro\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\envs\pro\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\envs\pro\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# d:\envs\pro\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\envs\pro\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\envs\pro\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\envs\pro\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\envs\pro\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\envs\pro\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import keras

# %%
plt.figure(figsize=(16,9))
min1 = Image.open("min.jpg")

print(min1.height,min1.size)
plt.subplot(1,3,1)
plt.title(min1.size)
plt.imshow(min1)


me = load_img("me.jpg")
plt.subplot(1,3,2)
plt.title(me.size)
plt.imshow(me)

max1 = load_img("max.jpg")
plt.subplot(1,3,3)
plt.title(max1.size)
plt.imshow(max1)
# Out:
# 3968 (2976, 3968)

# %%
from imgaug import augmenters as iaa

seq = iaa.Sequential([
#     iaa.Crop(px=(0, 16)), # crop images from each side by 0 to 16px (randomly chosen)
#     iaa.Fliplr(0.5), # horizontally flip 50% of the images
#     iaa.GaussianBlur(sigma=(0, 3.0)) # blur images with a sigma of 0 to 3.0
    iaa.Affine(scale=(0.5,2))
])


images_aug = seq(image=max1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-80c8ff989e79> in <module>
#       9
#      10
# ---> 11 images_aug = seq(image=max1)
#
# d:\envs\pro\lib\site-packages\imgaug\augmenters\meta.py in __call__(self, *args, **kwargs)
#    2006     def __call__(self, *args, **kwargs):
#    2007         """Alias for :func:`~imgaug.augmenters.meta.Augmenter.augment`."""
# -> 2008         return self.augment(*args, **kwargs)
#    2009
#    2010     def pool(self, processes=None, maxtasksperchild=None, seed=None):
#
# d:\envs\pro\lib\site-packages\imgaug\augmenters\meta.py in augment(self, return_batch, hooks, **kwargs)
#    1929                 "augment(), not both of them.")
#    1930             images = [kwargs["image"]]
# -> 1931             iabase._warn_on_suspicious_single_image_shape(images[0])
#    1932         else:
#    1933             images = kwargs.get("images", None)
#
# d:\envs\pro\lib\site-packages\imgaug\augmenters\base.py in _warn_on_suspicious_single_image_shape(image)
#      46     # We don't react to (1, 1, C) though, mostly because that is used in many
#      47     # unittests.
# ---> 48     if image.ndim == 3 and image.shape[-1] >= 32 and image.shape[0:2] != (1, 1):
#      49         ia.warn(
#      50             "You provided a numpy array of shape %s as a "
#
# AttributeError: 'JpegImageFile' object has no attribute 'ndim'
