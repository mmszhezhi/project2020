# %%
import imageio
import imgaug as ia
from imgaug import augmenters as iaa
import matplotlib.pyplot as plt
# %matplotlib inline

image = imageio.imread("https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png")

print("Original:")
ia.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# d:\envs\pro\lib\site-packages\imageio\plugins\pillow.py in pil_try_read(im)
#     668         # this will raise an IOError if the file is not readable
# --> 669         im.getdata()[0]
#     670     except IOError as e:
#
# d:\envs\pro\lib\site-packages\PIL\Image.py in getdata(self, band)
#    1276
# -> 1277         self.load()
#    1278         if band is not None:
#
# d:\envs\pro\lib\site-packages\PIL\ImageFile.py in load(self)
#     232                             try:
# --> 233                                 s = read(self.decodermaxblock)
#     234                             except (IndexError, struct.error):
#
# d:\envs\pro\lib\site-packages\PIL\PngImagePlugin.py in load_read(self, read_bytes)
#     860
# --> 861         return self.fp.read(read_bytes)
#     862
#
# d:\envs\pro\lib\site-packages\imageio\core\request.py in read(self, n)
#     517                 if want_more > 0:
# --> 518                     more = self.f.read(want_more)
#     519                     if len(more) < want_more:
#
# d:\python37\Lib\http\client.py in read(self, amt)
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#
# d:\python37\Lib\http\client.py in readinto(self, b)
#     500         # (for example, reading in 1k chunks)
# --> 501         n = self.fp.readinto(b)
#     502         if not n and b:
#
# d:\python37\Lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# d:\python37\Lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#
# d:\python37\Lib\ssl.py in read(self, len, buffer)
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-1b6e941791dd> in <module>
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#       6
# ----> 7 image = imageio.imread("https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png")
#       8
#       9 print("Original:")
#
# d:\envs\pro\lib\site-packages\imageio\core\functions.py in imread(uri, format, **kwargs)
#     263
#     264     # Get reader and read first
# --> 265     reader = read(uri, format, "i", **kwargs)
#     266     with reader:
#     267         return reader.get_data(0)
#
# d:\envs\pro\lib\site-packages\imageio\core\functions.py in get_reader(uri, format, mode, **kwargs)
#     184
#     185     # Return its reader object
# --> 186     return format.get_reader(request)
#     187
#     188
#
# d:\envs\pro\lib\site-packages\imageio\core\format.py in get_reader(self, request)
#     168                 "Format %s cannot read in %s mode" % (self.name, modename)
#     169             )
# --> 170         return self.Reader(self, request)
#     171
#     172     def get_writer(self, request):
#
# d:\envs\pro\lib\site-packages\imageio\core\format.py in __init__(self, format, request)
#     219             self._request = request
#     220             # Open the reader/writer
# --> 221             self._open(**self.request.kwargs.copy())
#     222
#     223         @property
#
# d:\envs\pro\lib\site-packages\imageio\plugins\pillow.py in _open(self, pilmode, as_gray, ignoregamma)
#     296     class Reader(PillowFormat.Reader):
#     297         def _open(self, pilmode=None, as_gray=False, ignoregamma=True):
# --> 298             return PillowFormat.Reader._open(self, pilmode=pilmode, as_gray=as_gray)
#     299
#     300         def _get_data(self, index):
#
# d:\envs\pro\lib\site-packages\imageio\plugins\pillow.py in _open(self, pilmode, as_gray)
#     133             if self._im.palette and self._im.palette.dirty:
#     134                 self._im.palette.rawmode_saved = self._im.palette.rawmode
# --> 135             pil_try_read(self._im)
#     136             # Store args
#     137             self._kwargs = dict(
#
# d:\envs\pro\lib\site-packages\imageio\plugins\pillow.py in pil_try_read(im)
#     678             % (im.filename, pillow_error_message, site)
#     679         )
# --> 680         raise ValueError(error_message)
#     681
#     682
#
# ValueError: Could not load ""
# Reason: "The read operation timed out"
# Please see documentation at: http://pillow.readthedocs.io/en/latest/installation.html#external-libraries

# %%
ia.seed(4)
rotate = iaa.Affine(rotate=(-180, 180))
crop = iaa.Crop(percent=(0, 0.3))
mul = iaa.Multiply((0.5,3.5), per_channel=0.01)
f,ax = plt.subplots(4,6,figsize=(16,9))
for i in range(4):
    for j in range(6):   
        image_aug = mul(image=image)
        ax[i][j].set_title(image_aug.shape)
        ax[i][j].set_xticks([])
        ax[i][j].set_yticks([])
        
        ax[i][j].imshow(image_aug)

# %%
import numpy as np

images = [image, image, image, image]
rotate = iaa.Affine(rotate=(-180, 180))
images_aug = rotate(images=images)

print("Augmented batch:")
ia.imshow(np.hstack(images_aug))
# Out:
# Augmented batch:

# %%
# Out:
# 4

# %%
seq = iaa.Sequential([
#     iaa.Affine(rotate=(-25, 25)),
#     iaa.AdditiveGaussianNoise(scale=(10, 60)),
    iaa.Crop(percent=(0, 0.1))
])
print(type(seq))
images_aug = seq(images=images)

print("Augmented:")
ia.imshow(np.hstack(images_aug))
# Out:
# <class 'imgaug.augmenters.meta.Sequential'>
# Augmented:

# %%
ia.seed(4)
rotate = iaa.Affine(rotate=(-180, 180))
crop = iaa.Crop(percent=(0, 0.3))
mul = iaa.Multiply((0.5,3.5), per_channel=0.01)
f,ax = plt.subplots(4,6,figsize=(16,9))
for i in range(4):
    for j in range(6):   
        image_aug = mul(image=image)
        ax[i][j].set_title(image_aug.shape)
        ax[i][j].set_xticks([])
        ax[i][j].set_yticks([])
        
        ax[i][j].imshow(image_aug)
