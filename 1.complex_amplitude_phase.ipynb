# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
data = np.linspace(-5,5,1000)
f = 1
b = 0 

f1 = lambda x,b: np.sin(2*np.pi*f*x + b)

# %%
plt.plot(data,f1(data,0))

# %%
plt.plot(np.fft.fft(f1(data,0)))
# Out:
# d:\python37\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
result = np.fft.fft(f1(data,0))

# %%
result.imag
# Out:
# array([ 0.00000000e+00, -1.00873456e-01, -2.08036323e-01, -3.29157265e-01,
#        -4.75351435e-01, -6.65282393e-01, -9.35091428e-01, -1.36787636e+00,
#        -2.21094374e+00, -4.68932218e+00, -4.99420788e+02,  5.28998015e+00,
#         2.74028453e+00,  1.88975985e+00,  1.46142016e+00,  1.20184222e+00,
#         1.02678324e+00,  9.00172683e-01,  8.03972410e-01,  7.28151445e-01,
#         6.66681180e-01,  6.15716515e-01,  5.72686843e-01,  5.35806634e-01,
#         5.03795740e-01,  4.75711503e-01,  4.50843762e-01,  4.28646847e-01,
#         4.08694204e-01,  3.90647298e-01,  3.74233811e-01,  3.59232051e-01,
#         3.45459583e-01,  3.32764809e-01,  3.21020639e-01,  3.10119672e-01,
#         2.99970474e-01,  2.90494679e-01,  2.81624703e-01,  2.73301925e-01,
#         2.65475228e-01,  2.58099818e-01,  2.51136260e-01,  2.44549692e-01,
#         2.38309165e-01,  2.32387107e-01,  2.26758863e-01,  2.21402315e-01,
# ...

# %%
data = np.linspace(-5,5,100)
fig = plt.figure(figsize=(15,9))
for p in [0*np.pi]:
    
    result = np.fft.fft(f1(data,p))
#     print(result)
#     plt.plot(result.real)
#     plt.plot(result.imag)
    plt.plot(np.angle(result))
#     plt.scatter(data,np.angle(result))
