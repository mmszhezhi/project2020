# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import time
import matplotlib.pyplot as plt

class data_generator:
    def __init__(self,mod="random",width=1000,height=3):
        self.width = width
        self.height = height
        self.mod = mod

    def __next__(self):
        # if self.mod == "random":
        d1 = np.linspace(0, self.width-1, self.width).reshape([1,-1])
        d3 = np.vstack([d1]*self.height)
        f = np.random.randint(1,20,self.height).reshape([1,-1])
        f = np.array([5,3,50]).reshape([1,-1])
        f = np.array([5,5,5]).reshape([1,-1])
        theta = np.random.random(self.height) * np.pi
        theta = theta.reshape([1,-1])
        f = np.array([5,5,5]).reshape([1,-1])
        f1 = lambda x:10*np.sin(f.T*x + theta.T)
        return d3,f1(d3),f1

# %%
gen = data_generator(height=3)

# %%
origin,data,f = next(gen)

# %%
data.shape
# Out:
# (3, 1000)

# %%
d = data.sum(axis=0)

# %%
plt.plot(d)

# %%
show(d)

# %%
f([11111,1])
# Out:
# array([[9.97599173, 9.97599173]])

# %%
f
# Out:
# <function __main__.data_generator.__next__.<locals>.<lambda>(x)>

# %%
f2 = lambda x: 10*np.sin(2*np.pi*2*x + 0.1*np.pi)

# %%
f2(2)
# Out:
# 3.0901699437494816

# %% [markdown]
# f2(34)

# %%
f2(221)
# Out:
# 3.0901699437517047

# %%
f4 = lambda x:np.sin(10*x)

# %%
plt.plot(f4(np.linspace(0,100,5000)))

# %%
f3 = lambda x,t,f:np.sin(f*x + t*np.pi)

# %%
plt.plot(f3(np.array(range(0,20)),0,1))

# %%
def show(data):
    for d in data:
        plt.plot(d)
    plt.show()

# %%
l = list(map(f3,[np.linspace(0,100,500)]*3,[1,2,3],[0.1,0.2,2]))

# %%
show(l)

# %%
re =np.array(l)

# %%
re.shape
# Out:
# (3, 500)

# %%
r1 = re.sum(axis=0)

# %%
r1.shape
# Out:
# (500,)

# %%
plt.plot(r1)

# %%
for d in l:
    plt.plot(d)
plt.show()
